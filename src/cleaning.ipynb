# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/bitcoin_dataset.csv')

# %%
df.replace('?', np.nan, inplace=True)

# %%
df
# Out:
#                      date      difficulty sent_addresses     send_usd  \
# 0     2009-01-03 00-00-00               1            NaN          NaN
# 1                     NaN             NaN            NaN          NaN
# 2                     NaN             NaN            NaN          NaN
# 3                     NaN             NaN            NaN          NaN
# 4                     NaN             NaN            NaN          NaN
# ...                   ...             ...            ...          ...
# 4576                  NaN  14363025673660         386824  16363800845
# 4577                  NaN  14363025673660         350835  12231055118
# 4578                  NaN  14348541098817         269883  15303994562
# 4579                  NaN  13672594272814         187721   7945136415
# 4580                  NaN             NaN            NaN          NaN
#
#         market_cap confirmation_time transactions median_transaction_size  \
# ...

# %%
df[["date"]][df["date"].isnull()]
# Out:
#      date
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# ...   ...
# 4576  NaN
# 4577  NaN
# 4578  NaN
# 4579  NaN
# 4580  NaN
#
# [4580 rows x 1 columns]
